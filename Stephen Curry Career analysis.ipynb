# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("C:\\Users\\Singh\\Downloads\\archive\\Stephen Curry Regularseason Stats.csv")
data.head()
# Out:
#   Season_year Season_div      Date  OPP Result  T Score  O Score   MIN     FG  \
# 0   2009-2010    Regular  Wed 4/14  POR      W      122      116  48.0  13-25
# 1   2009-2010    Regular  Tue 4/13  UTA      L       94      103  41.0   5-15
# 2   2009-2010    Regular  Sun 4/11  OKC      W      120      117  35.0   9-16
# 3   2009-2010    Regular  Sat 4/10  LAC      L      104      107  41.0  10-19
# 4   2009-2010    Regular   Wed 4/7  MIN      W      116      107  44.0  12-22
#
#    FGM  ...  FTM  FTA    FT%  REB  AST  BLK STL  PF  TO  PTS
# 0   13  ...   12   12  100.0    9    8    1   2   0   2   42
# 1    5  ...    6    6  100.0    5    6    0   2   4   2   17
# 2    9  ...    4    6   66.7    7    7    0   1   2   5   25
# 3   10  ...    4    4  100.0    9    4    0   3   5   3   29
# 4   12  ...    0    0    0.0    8   14    0   7   4   4   27
#
# [5 rows x 27 columns]

# %%
data.shape
# Out:
# (881, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season_year  881 non-null    object
#  1   Season_div   881 non-null    object
#  2   Date         881 non-null    object
#  3   OPP          881 non-null    object
#  4   Result       881 non-null    object
#  5   T Score      881 non-null    int64
#  6   O Score      881 non-null    int64
#  7   MIN          881 non-null    float64
#  8   FG           881 non-null    object
#  9   FGM          881 non-null    int64
#  10  FGA          881 non-null    int64
#  11  FG%          881 non-null    float64
#  12  3PT          881 non-null    object
#  13  3PTM         881 non-null    int64
#  14  3PTA         881 non-null    int64
#  15  3P%          881 non-null    float64
#  16  FT           881 non-null    object
#  17  FTM          881 non-null    int64
# ...

# %%
data.drop(["T Score","O Score","MIN","Season_div","PF"],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season_year  881 non-null    object
#  1   Date         881 non-null    object
#  2   OPP          881 non-null    object
#  3   Result       881 non-null    object
#  4   FG           881 non-null    object
#  5   FGM          881 non-null    int64
#  6   FGA          881 non-null    int64
#  7   FG%          881 non-null    float64
#  8   3PT          881 non-null    object
#  9   3PTM         881 non-null    int64
#  10  3PTA         881 non-null    int64
#  11  3P%          881 non-null    float64
#  12  FT           881 non-null    object
#  13  FTM          881 non-null    int64
#  14  FTA          881 non-null    int64
#  15  FT%          881 non-null    float64
#  16  REB          881 non-null    int64
#  17  AST          881 non-null    int64
# ...

# %%
data.drop(["FG","3PT","FT"],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season_year  881 non-null    object
#  1   Date         881 non-null    object
#  2   OPP          881 non-null    object
#  3   Result       881 non-null    object
#  4   FGM          881 non-null    int64
#  5   FGA          881 non-null    int64
#  6   FG%          881 non-null    float64
#  7   3PTM         881 non-null    int64
#  8   3PTA         881 non-null    int64
#  9   3P%          881 non-null    float64
#  10  FTM          881 non-null    int64
#  11  FTA          881 non-null    int64
#  12  FT%          881 non-null    float64
#  13  REB          881 non-null    int64
#  14  AST          881 non-null    int64
#  15  BLK          881 non-null    int64
#  16  STL          881 non-null    int64
#  17  TO           881 non-null    int64
# ...

# %%
data.describe()
# Out:
#               FGM         FGA         FG%        3PTM        3PTA         3P%  \
# count  881.000000  881.000000  881.000000  881.000000  881.000000  881.000000
# mean     8.438138   17.767310   46.966969    3.847900    9.000000   41.732804
# std      3.366425    5.243968   12.626236    2.409644    4.006812   18.613253
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.000000   14.000000   38.900000    2.000000    6.000000   30.000000
# 50%      8.000000   18.000000   47.400000    4.000000    9.000000   41.700000
# 75%     11.000000   21.000000   55.600000    5.000000   12.000000   53.800000
# max     20.000000   36.000000  100.000000   13.000000   22.000000  100.000000
#
#               FTM         FTA         FT%         REB         AST         BLK  \
# count  881.000000  881.000000  881.000000  881.000000  881.000000  881.000000
# mean     3.920545    4.314415   78.728150    4.743473    6.515323    0.234960
# ...

# %%
data["Result"].value_counts()
# Out:
# Result
# W    574
# L    307
# Name: count, dtype: int64

# %%
data["Result"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Result'>

# %%
data.head()
# Out:
#   Season_year      Date  OPP Result  FGM  FGA   FG%  3PTM  3PTA   3P%  FTM  \
# 0   2009-2010  Wed 4/14  POR      W   13   25  52.0     4     6  66.7   12
# 1   2009-2010  Tue 4/13  UTA      L    5   15  33.3     1     4  25.0    6
# 2   2009-2010  Sun 4/11  OKC      W    9   16  56.3     3     6  50.0    4
# 3   2009-2010  Sat 4/10  LAC      L   10   19  52.6     5    10  50.0    4
# 4   2009-2010   Wed 4/7  MIN      W   12   22  54.5     3     5  60.0    0
#
#    FTA    FT%  REB  AST  BLK  STL  TO  PTS
# 0   12  100.0    9    8    1    2   2   42
# 1    6  100.0    5    6    0    2   2   17
# 2    6   66.7    7    7    0    1   5   25
# 3    4  100.0    9    4    0    3   3   29
# 4    0    0.0    8   14    0    7   4   27

# %%
Total_3PTM = data['3PTM'].sum()
Total_3PTM
# Out:
# 3390

# %%
steph_stats= data.groupby('OPP')
stat_sheet=steph_stats[['PTS','3PTM','FGM','FTM','REB','AST','BLK','STL']].sum()
stat_sheet
# Out:
#       PTS  3PTM  FGM  FTM  REB  AST  BLK  STL
# OPP
# ATL   476    61  158   99   89  129    6   31
# BKN   562    84  193   92  102  125    3   42
# BOS   569    94  186  103  106  129    7   36
# CHA   534    87  187   73   90  141   10   27
# CHI   569    78  200   91  128  142    7   41
# CLE   562    93  192   85   98  137    7   34
# DAL   936   146  322  146  175  266    5   59
# DEN   960   160  332  136  181  234   12   57
# DET   497    72  168   89   95  137    1   42
# HOU   955   147  333  142  181  273   13   62
# IND   481    74  161   85  103  158    5   36
# LAC  1199   191  401  206  223  274   10   82
# LAL   838   118  292  136  195  279    4   65
# MEM   985   159  336  154  196  243   11   59
# MIA   527    90  179   79  113  143    5   28
# MIL   455    64  156   79   95  129   10   31
# MIN  1006   153  347  159  209  286   11   80
# NOP   898   147  304  143  150  242    4   61
# NYK   585   110  198   79  121  142    4   30
# ...

# %%
#Top 5 teams Stephen Curry has scored most points against
stat_sheet['PTS'].sort_values(ascending=False).head()
# Out:
# OPP
# LAC    1199
# OKC    1141
# PHX    1046
# POR    1023
# SAC    1014
# Name: PTS, dtype: int64

# %%
#Top 5 teams Stephen Curry has scored most 3 pointers against
stat_sheet['3PTM'].sort_values(ascending=False).head()
# Out:
# OPP
# LAC    191
# OKC    184
# PHX    169
# SAC    164
# POR    162
# Name: 3PTM, dtype: int64

# %%
#Top 5 teams Stephen Curry has most field goals against
stat_sheet['FGM'].sort_values(ascending=False).head()
# Out:
# OPP
# LAC    401
# OKC    397
# PHX    365
# POR    351
# MIN    347
# Name: FGM, dtype: int64

# %%
#Top 5 teams Stephen Curry has scored most free throw against
stat_sheet['FTM'].sort_values(ascending=False).head()
# Out:
# OPP
# LAC    206
# SAC    164
# OKC    163
# POR    159
# MIN    159
# Name: FTM, dtype: int64

# %%
#Top 5 teams Stephen Curry has most rebound against
stat_sheet['REB'].sort_values(ascending=False).head()
# Out:
# OPP
# LAC    223
# OKC    222
# SAC    215
# MIN    209
# PHX    203
# Name: REB, dtype: int64

# %%
#Top 5 teams Stephen Curry has most assist against
stat_sheet['AST'].sort_values(ascending=False).head()
# Out:
# OPP
# SAC    303
# OKC    291
# PHX    290
# MIN    286
# LAL    279
# Name: AST, dtype: int64

# %%
#Top 5 teams Stephen Curry has most block against
stat_sheet['BLK'].sort_values(ascending=False).head()
# Out:
# OPP
# HOU    13
# PHX    12
# DEN    12
# MIN    11
# POR    11
# Name: BLK, dtype: int64

# %%
#Top 5 teams Stephen Curry has most steal against
stat_sheet['STL'].sort_values(ascending=False).head()
# Out:
# OPP
# SAC    84
# LAC    82
# MIN    80
# OKC    66
# PHX    66
# Name: STL, dtype: int64

# %% [markdown]
# ### Stephen Curry's career high in PTS, 3PTM, FGM, AST, STL, BLK, REB

# %%
# most points scored in a single match
data['PTS'].max()
# Out:
# 62

# %%
# most 3 pointers made in a single match
data['3PTM'].max()
# Out:
# 13

# %%
# most field goals made in a single match
data['FGM'].max()
# Out:
# 20

# %%
# most assist in a single match
data['AST'].max()
# Out:
# 16

# %%
#most steal in a single match
data['STL'].max()
# Out:
# 7

# %%
# most blocks in a single match
data['BLK'].max()
# Out:
# 2

# %%
# most rebounds in a single match
data['REB'].max()
# Out:
# 14

# %%
# Top 5 Highest points scored by Stephen Curry
data[['PTS','OPP','Date','Season_year']].set_index('PTS').sort_values('PTS',ascending=False).head()
# Out:
#      OPP       Date Season_year
# PTS
# 62   POR    Sun 1/3   2020-2021
# 57   DAL    Sat 2/6   2020-2021
# 54   NYK   Wed 2/27   2012-2013
# 53   NOP  Sat 10/31   2015-2016
# 53   DEN   Mon 4/12   2020-2021

# %%
# Top 5 Highest 3 pointers made by Stephen Curry
data[['3PTM','OPP','Date','Season_year']].set_index('3PTM').sort_values('3PTM',ascending=False).head()
# Out:
#       OPP      Date Season_year
# 3PTM
# 13    NOP  Mon 11/7   2016-2017
# 12    OKC  Sat 2/27   2015-2016
# 11    DAL  Sun 1/13   2018-2019
# 11    CHA   Wed 2/1   2016-2017
# 11    MIN  Fri 3/29   2018-2019

# %%
data.head()
# Out:
#   Season_year      Date  OPP Result  FGM  FGA   FG%  3PTM  3PTA   3P%  FTM  \
# 0   2009-2010  Wed 4/14  POR      W   13   25  52.0     4     6  66.7   12
# 1   2009-2010  Tue 4/13  UTA      L    5   15  33.3     1     4  25.0    6
# 2   2009-2010  Sun 4/11  OKC      W    9   16  56.3     3     6  50.0    4
# 3   2009-2010  Sat 4/10  LAC      L   10   19  52.6     5    10  50.0    4
# 4   2009-2010   Wed 4/7  MIN      W   12   22  54.5     3     5  60.0    0
#
#    FTA    FT%  REB  AST  BLK  STL  TO  PTS
# 0   12  100.0    9    8    1    2   2   42
# 1    6  100.0    5    6    0    2   2   17
# 2    6   66.7    7    7    0    1   5   25
# 3    4  100.0    9    4    0    3   3   29
# 4    0    0.0    8   14    0    7   4   27

# %%
data.drop('TO',axis=1,inplace=True)
data.head()
# Out:
#   Season_year      Date  OPP Result  FGM  FGA   FG%  3PTM  3PTA   3P%  FTM  \
# 0   2009-2010  Wed 4/14  POR      W   13   25  52.0     4     6  66.7   12
# 1   2009-2010  Tue 4/13  UTA      L    5   15  33.3     1     4  25.0    6
# 2   2009-2010  Sun 4/11  OKC      W    9   16  56.3     3     6  50.0    4
# 3   2009-2010  Sat 4/10  LAC      L   10   19  52.6     5    10  50.0    4
# 4   2009-2010   Wed 4/7  MIN      W   12   22  54.5     3     5  60.0    0
#
#    FTA    FT%  REB  AST  BLK  STL  PTS
# 0   12  100.0    9    8    1    2   42
# 1    6  100.0    5    6    0    2   17
# 2    6   66.7    7    7    0    1   25
# 3    4  100.0    9    4    0    3   29
# 4    0    0.0    8   14    0    7   27

# %%
data.to_csv('steph_curry_analysis.csv')
